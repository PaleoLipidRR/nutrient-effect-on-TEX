# %%
import pandas as pd
import pygwalker as pyg
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import proplot as plot
import matplotlib as mpl

# %%
# set the path to local folder other than github

### 1.4.1 Local path on PC
local_documents_path = '/home/ronnie/Documents' ### this is the path when code is run on Linux

### 1.4.2 Path to github folder
gitpath_idx = os.getcwd().find('nutrient-effect-on-TEX')+len('nutrient-effect-on-TEX')
local_github_path = os.getcwd()[:gitpath_idx]

### 1.4.3 Path to OneDrive folder
local_onedrive_path = '/home/ronnie/OneDrive'

# %%
fpath = fr'{local_github_path}/spreadsheets'
fname = 'coretop_df_full_011525_tmp.csv'

coretop_df = pd.read_csv(f'{fpath}/{fname}')
coretop_df
# Out:
#                sampleID          core_name core_type  sample_depth_start  \
# 0     TEXAS_PSM_RR00002      KNR195-5 MC11        MC                 6.0
# 1     TEXAS_PSM_RR00005      KNR195-5 MC18        MC                 4.0
# 2     TEXAS_PSM_RR00007      KNR195-5 MC25        MC                 5.0
# 3     TEXAS_PSM_RR00008      KNR195-5 MC33        MC                 3.0
# 4     TEXAS_PSM_RR00009      KNR195-5 MC34        MC                 4.0
# ...                 ...                ...       ...                 ...
# 2017  TEXAS_PSM_RR02077     SY201710_LD-18       NaN                 NaN
# 2018  TEXAS_PSM_RR02078  DO201207-08_QD11a       NaN                 NaN
# 2019  TEXAS_PSM_RR02079   DO201207-08_QD41       NaN                 NaN
# 2020  TEXAS_PSM_RR02080   DO201207-08_E503       NaN                 NaN
# 2021  TEXAS_PSM_RR02081     SY201710_LD-21       NaN                 NaN
#
#       sample_depth_end  Latitude  Longitude  modernWaterDepth     TEX86  \
# 0                  8.0   -1.5327   -86.7852            2288.0  0.602873
# 1                  6.0   -3.9690   -81.3100            1024.0  0.599447
# 2                  7.0   -3.5830   -81.1650             381.0  0.617192
# 3                  5.0   -3.2237   -82.9142            2949.0  0.605147
# 4                  6.0   -3.5975   -83.9632            3224.0  0.588670
# ...                ...       ...        ...               ...       ...
# 2017               NaN   20.5700   113.8000              89.0  0.595556
# 2018               NaN   20.7000   113.3700              81.0  0.512500
# 2019               NaN   20.1400   112.0600              87.0  0.585859
# 2020               NaN   19.2000   112.2900             189.0  0.651376
# 2021               NaN   19.6600   114.6400            1310.0  0.654275
#
#        fGDGT_0  ...  thermocline_nitrate_depthIntegral  region_ID  \
# 0     0.330589  ...                           5.318187       10.0
# 1     0.282415  ...                           4.969550       10.0
# 2     0.292011  ...                           4.208444       10.0
# 3     0.309270  ...                           6.493748       10.0
# 4     0.344233  ...                           6.708450       10.0
# ...        ...  ...                                ...        ...
# 2017  0.236000  ...                           0.170105       38.0
# 2018  0.281000  ...                           0.258762       38.0
# 2019  0.236000  ...                           0.105737       38.0
# 2020  0.237000  ...                           0.065285       38.0
# 2021  0.299000  ...                           0.110302       38.0
#
#                    regionName  TEX_RI_zhang16  deltaRI_zhang16  TEX_RI_new  \
# 0     East Equatorial Pacific        2.332461        -0.009145    2.490897
# 1     East Equatorial Pacific        2.321423        -0.245102    2.480441
# 2     East Equatorial Pacific        2.379435        -0.123700    2.534593
# 3     East Equatorial Pacific        2.339831        -0.087586    2.497838
# 4     East Equatorial Pacific        2.287212         0.038298    2.447554
# ...                       ...             ...              ...         ...
# 2017          South China Sea        2.308981        -0.292019    2.468567
# 2018          South China Sea        2.067394        -0.457606    2.215107
# 2019          South China Sea        2.278413        -0.373587    2.438974
# 2020          South China Sea        2.497086        -0.149914    2.638914
# 2021          South China Sea        2.507420         0.211420    2.647761
#
#      deltaRI_new QC_flag2  pred_tex tex_residuals
# 0       0.149291  include  0.605526     -0.002653
# 1      -0.086083  include  0.592135      0.007312
# 2       0.031458  include  0.600764      0.016428
# 3       0.070420  include  0.584390      0.020758
# 4       0.198641  include  0.590421     -0.001751
# ...          ...      ...       ...           ...
# 2017   -0.132433  include  0.633144     -0.037588
# 2018   -0.309893  include  0.632145     -0.119645
# 2019   -0.213026  include  0.640826     -0.054967
# 2020   -0.008086  include  0.647441      0.003935
# 2021    0.351761  include  0.639453      0.014822
#
# [2022 rows x 46 columns]

# %%
coretop_df.columns
# Out:
# Index(['sampleID', 'core_name', 'core_type', 'sample_depth_start',
#        'sample_depth_end', 'Latitude', 'Longitude', 'modernWaterDepth',
#        'TEX86', 'fGDGT_0', 'fGDGT_1', 'fGDGT_2', 'fGDGT_3', 'fGDGT_cren',
#        'fGDGT_cren_prime', 'BIT', 'publicationYear', 'reference_name',
#        'remark', 'reference_link', 'RI_zhang16', 'RI_zhang16_revised',
#        'RI_0to5', 'gdgt23ratio', 'methaneIndex', 'gdgtZeroOverZeroCren',
#        'QC_flag', 'match_lat', 'match_lon', 'match_depth', 'SST',
#        'thermocline_depth', 'thermocline_T', 'thermocline_T_depthIntegral',
#        'SSN', 'thermocline_nitrate', 'thermocline_nitrate_depthIntegral',
#        'region_ID', 'regionName', 'TEX_RI_zhang16', 'deltaRI_zhang16',
#        'TEX_RI_new', 'deltaRI_new', 'QC_flag2', 'pred_tex', 'tex_residuals'],
#       dtype='object')

# %%
features = ['Latitude','Longitude','sampleID',
            'core_name','modernWaterDepth',
            'regionName','reference_name',
            'TEX86','BIT','tex_residuals',
            'SST','thermocline_depth', 'thermocline_T', 'thermocline_T_depthIntegral',
            'SSN', 'thermocline_nitrate', 'thermocline_nitrate_depthIntegral',
            'QC_flag']
df = coretop_df[features]
df
# Out:
#       Latitude  Longitude           sampleID          core_name  \
# 0      -1.5327   -86.7852  TEXAS_PSM_RR00002      KNR195-5 MC11
# 1      -3.9690   -81.3100  TEXAS_PSM_RR00005      KNR195-5 MC18
# 2      -3.5830   -81.1650  TEXAS_PSM_RR00007      KNR195-5 MC25
# 3      -3.2237   -82.9142  TEXAS_PSM_RR00008      KNR195-5 MC33
# 4      -3.5975   -83.9632  TEXAS_PSM_RR00009      KNR195-5 MC34
# ...        ...        ...                ...                ...
# 2017   20.5700   113.8000  TEXAS_PSM_RR02077     SY201710_LD-18
# 2018   20.7000   113.3700  TEXAS_PSM_RR02078  DO201207-08_QD11a
# 2019   20.1400   112.0600  TEXAS_PSM_RR02079   DO201207-08_QD41
# 2020   19.2000   112.2900  TEXAS_PSM_RR02080   DO201207-08_E503
# 2021   19.6600   114.6400  TEXAS_PSM_RR02081     SY201710_LD-21
#
#       modernWaterDepth               regionName reference_name     TEX86  \
# 0               2288.0  East Equatorial Pacific     this study  0.602873
# 1               1024.0  East Equatorial Pacific     this study  0.599447
# 2                381.0  East Equatorial Pacific     this study  0.617192
# 3               2949.0  East Equatorial Pacific     this study  0.605147
# 4               3224.0  East Equatorial Pacific     this study  0.588670
# ...                ...                      ...            ...       ...
# 2017              89.0          South China Sea        Wei2020  0.595556
# 2018              81.0          South China Sea        Wei2020  0.512500
# 2019              87.0          South China Sea        Wei2020  0.585859
# 2020             189.0          South China Sea        Wei2020  0.651376
# 2021            1310.0          South China Sea        Wei2020  0.654275
#
#              BIT  tex_residuals        SST  thermocline_depth  thermocline_T  \
# 0       0.026817      -0.002653  23.409010               25.0      20.861510
# 1       0.033434       0.007312  22.386110               15.0      20.119310
# 2       0.029310       0.016428  23.418110               15.0      20.730000
# 3       0.035502       0.020758  22.126291               35.0      18.431309
# 4       0.032600      -0.001751  22.478000               35.0      18.941510
# ...          ...            ...        ...                ...            ...
# 2017 -999.000000      -0.037588  26.130590               65.0      23.082390
# 2018 -999.000000      -0.119645  26.039110               65.0      23.107200
# 2019 -999.000000      -0.054967  26.262810               35.0      24.743010
# 2020 -999.000000       0.003935  26.764490               40.0      25.169900
# 2021 -999.000000       0.014822  26.787409               65.0      23.185810
#
#       thermocline_T_depthIntegral       SSN  thermocline_nitrate  \
# 0                       22.520248  4.094641             8.300386
# 1                       21.319408  4.326240             6.462469
# 2                       22.093159  3.517715             5.804398
# 3                       20.624900  4.120540            11.105642
# 4                       21.165697  5.059356            10.533526
# ...                           ...       ...                  ...
# 2017                    24.996754  0.160042             0.908693
# 2018                    24.907140  0.175227             1.110894
# 2019                    25.685574  0.178591             0.058804
# 2020                    26.278778  0.122501             0.009576
# 2021                    25.562536  0.077976             0.789886
#
#       thermocline_nitrate_depthIntegral  QC_flag
# 0                              5.318187  include
# 1                              4.969550  include
# 2                              4.208444  include
# 3                              6.493748  include
# 4                              6.708450  include
# ...                                 ...      ...
# 2017                           0.170105  include
# 2018                           0.258762  include
# 2019                           0.105737  include
# 2020                           0.065285  include
# 2021                           0.110302  include
#
# [2022 rows x 18 columns]

# %%
pyg.walk(df)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00062c76d3ba2f56RbrQ8zlENyVTG51m" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00062c76d3ba2f56RbrQ8zlENyVTG51m") {
#             var iframe = document.getElementById("gwalker-00062c76d3ba2f56RbrQ8zlENyVTG51m");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
