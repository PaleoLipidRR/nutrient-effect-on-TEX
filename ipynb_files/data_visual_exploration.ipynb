# %%
import pandas as pd
import pygwalker as pyg
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import proplot as plot
import matplotlib as mpl

# %%
# set the path to local folder other than github

### 1.4.1 Local path on PC
local_documents_path = '/home/ronnie/Documents' ### this is the path when code is run on Linux

### 1.4.2 Path to github folder
gitpath_idx = os.getcwd().find('nutrient-effect-on-TEX')+len('nutrient-effect-on-TEX')
local_github_path = os.getcwd()[:gitpath_idx]

### 1.4.3 Path to OneDrive folder
local_onedrive_path = '/home/ronnie/OneDrive'

# %%
fpath = fr'{local_github_path}/spreadsheets'
fname = 'coretop_df_full_011525_tmp.csv'

coretop_df = pd.read_csv(f'{fpath}/{fname}')
coretop_df
# Out:
#                sampleID          core_name core_type  sample_depth_start  \
# 0     TEXAS_PSM_RR00001         GeoB7702-3        GC                 5.0
# 1     TEXAS_PSM_RR00002      KNR195-5 MC11        MC                 6.0
# 2     TEXAS_PSM_RR00003      KNR195-5 MC12        MC                 0.0
# 3     TEXAS_PSM_RR00004      KNR195-5 MC16        MC                 0.0
# 4     TEXAS_PSM_RR00005      KNR195-5 MC18        MC                 4.0
# ...                 ...                ...       ...                 ...
# 2074  TEXAS_PSM_RR02077     SY201710_LD-18       NaN                 NaN
# 2075  TEXAS_PSM_RR02078  DO201207-08_QD11a       NaN                 NaN
# 2076  TEXAS_PSM_RR02079   DO201207-08_QD41       NaN                 NaN
# 2077  TEXAS_PSM_RR02080   DO201207-08_E503       NaN                 NaN
# 2078  TEXAS_PSM_RR02081     SY201710_LD-21       NaN                 NaN
#
#       sample_depth_end  Latitude  Longitude  modernWaterDepth     TEX86  \
# 0                  6.0   31.6517    34.0733             562.0  0.662000
# 1                  8.0   -1.5327   -86.7852            2288.0  0.602873
# 2                  1.0   -3.7105   -81.1153             378.0  0.570000
# 3                  1.0   -3.7502   -81.1358             379.0  0.572000
# 4                  6.0   -3.9690   -81.3100            1024.0  0.599447
# ...                ...       ...        ...               ...       ...
# 2074               NaN   20.5700   113.8000              89.0  0.595556
# 2075               NaN   20.7000   113.3700              81.0  0.512500
# 2076               NaN   20.1400   112.0600              87.0  0.585859
# 2077               NaN   19.2000   112.2900             189.0  0.651376
# 2078               NaN   19.6600   114.6400            1310.0  0.654275
#
#        fGDGT_0  ...  thermocline_nitrate_depthIntegral  region_ID  \
# 0          NaN  ...                           0.025728        NaN
# 1     0.330589  ...                           5.318187       10.0
# 2          NaN  ...                           4.208444        NaN
# 3          NaN  ...                           5.378340        NaN
# 4     0.282415  ...                           4.969550       10.0
# ...        ...  ...                                ...        ...
# 2074  0.236000  ...                           0.170105       38.0
# 2075  0.281000  ...                           0.258762       38.0
# 2076  0.236000  ...                           0.105737       38.0
# 2077  0.237000  ...                           0.065285       38.0
# 2078  0.299000  ...                           0.110302       38.0
#
#                    regionName  TEX_RI_zhang16  deltaRI_zhang16  TEX_RI_new  \
# 0                         NaN        2.535230              NaN    2.671335
# 1     East Equatorial Pacific        2.332461        -0.009145    2.490897
# 2                         NaN        2.229768              NaN    2.390579
# 3                         NaN        2.235811              NaN    2.396682
# 4     East Equatorial Pacific        2.321423        -0.245102    2.480441
# ...                       ...             ...              ...         ...
# 2074          South China Sea        2.308981        -0.292019    2.468567
# 2075          South China Sea        2.067394        -0.457606    2.215107
# 2076          South China Sea        2.278413        -0.373587    2.438974
# 2077          South China Sea        2.497086        -0.149914    2.638914
# 2078          South China Sea        2.507420         0.211420    2.647761
#
#      deltaRI_new QC_flag2  pred_tex tex_residuals
# 0            NaN  exclude  0.592688      0.069312
# 1       0.149291  include  0.602537      0.000336
# 2            NaN  exclude  0.598017     -0.028017
# 3            NaN  exclude  0.597470     -0.025470
# 4      -0.086083  include  0.589827      0.009620
# ...          ...      ...       ...           ...
# 2074   -0.132433  include  0.628749     -0.033194
# 2075   -0.309893  include  0.627801     -0.115301
# 2076   -0.213026  include  0.636040     -0.050181
# 2077   -0.008086  include  0.642319      0.009058
# 2078    0.351761  include  0.634738      0.019537
#
# [2079 rows x 46 columns]

# %%
coretop_df.columns
# Out:
# Index(['sampleID', 'core_name', 'core_type', 'sample_depth_start',
#        'sample_depth_end', 'Latitude', 'Longitude', 'modernWaterDepth',
#        'TEX86', 'fGDGT_0', 'fGDGT_1', 'fGDGT_2', 'fGDGT_3', 'fGDGT_cren',
#        'fGDGT_cren_prime', 'BIT', 'publicationYear', 'reference_name',
#        'remark', 'reference_link', 'RI_zhang16', 'RI_zhang16_revised',
#        'RI_0to5', 'gdgt23ratio', 'methaneIndex', 'gdgtZeroOverZeroCren',
#        'QC_flag', 'match_lat', 'match_lon', 'match_depth', 'SST',
#        'thermocline_depth', 'thermocline_T', 'thermocline_T_depthIntegral',
#        'SSN', 'thermocline_nitrate', 'thermocline_nitrate_depthIntegral',
#        'region_ID', 'regionName', 'TEX_RI_zhang16', 'deltaRI_zhang16',
#        'TEX_RI_new', 'deltaRI_new', 'QC_flag2', 'pred_tex', 'tex_residuals'],
#       dtype='object')

# %%
features = ['Latitude','Longitude','sampleID',
            'core_name','modernWaterDepth',
            'regionName','reference_name',
            'TEX86','BIT','tex_residuals',
            'SST','thermocline_depth', 'thermocline_T', 'thermocline_T_depthIntegral',
            'SSN', 'thermocline_nitrate', 'thermocline_nitrate_depthIntegral',
            'QC_flag']
df = coretop_df[features]
df
# Out:
#       Latitude  Longitude           sampleID          core_name  \
# 0      31.6517    34.0733  TEXAS_PSM_RR00001         GeoB7702-3
# 1      -1.5327   -86.7852  TEXAS_PSM_RR00002      KNR195-5 MC11
# 2      -3.7105   -81.1153  TEXAS_PSM_RR00003      KNR195-5 MC12
# 3      -3.7502   -81.1358  TEXAS_PSM_RR00004      KNR195-5 MC16
# 4      -3.9690   -81.3100  TEXAS_PSM_RR00005      KNR195-5 MC18
# ...        ...        ...                ...                ...
# 2074   20.5700   113.8000  TEXAS_PSM_RR02077     SY201710_LD-18
# 2075   20.7000   113.3700  TEXAS_PSM_RR02078  DO201207-08_QD11a
# 2076   20.1400   112.0600  TEXAS_PSM_RR02079   DO201207-08_QD41
# 2077   19.2000   112.2900  TEXAS_PSM_RR02080   DO201207-08_E503
# 2078   19.6600   114.6400  TEXAS_PSM_RR02081     SY201710_LD-21
#
#       modernWaterDepth               regionName reference_name     TEX86  \
# 0                562.0                      NaN  Castaneda2010  0.662000
# 1               2288.0  East Equatorial Pacific     this study  0.602873
# 2                378.0                      NaN     Chazen2011  0.570000
# 3                379.0                      NaN     Chazen2011  0.572000
# 4               1024.0  East Equatorial Pacific     this study  0.599447
# ...                ...                      ...            ...       ...
# 2074              89.0          South China Sea        Wei2020  0.595556
# 2075              81.0          South China Sea        Wei2020  0.512500
# 2076              87.0          South China Sea        Wei2020  0.585859
# 2077             189.0          South China Sea        Wei2020  0.651376
# 2078            1310.0          South China Sea        Wei2020  0.654275
#
#              BIT  tex_residuals        SST  thermocline_depth  thermocline_T  \
# 0       0.256000       0.069312  22.622210               55.0       19.00691
# 1       0.026817       0.000336  23.409010               25.0       20.86151
# 2    -999.000000      -0.028017  23.418110               15.0       20.73000
# 3    -999.000000      -0.025470  23.317910               15.0       20.58300
# 4       0.033434       0.009620  22.386110               15.0       20.11931
# ...          ...            ...        ...                ...            ...
# 2074 -999.000000      -0.033194  26.130590               65.0       23.08239
# 2075 -999.000000      -0.115301  26.039110               65.0       23.10720
# 2076 -999.000000      -0.050181  26.262810               35.0       24.74301
# 2077 -999.000000       0.009058  26.764490               40.0       25.16990
# 2078 -999.000000       0.019537  26.787409               65.0       23.18581
#
#       thermocline_T_depthIntegral       SSN  thermocline_nitrate  \
# 0                       21.589685  0.088246             0.003865
# 1                       22.520248  4.094641             8.300386
# 2                       22.093159  3.517715             5.804398
# 3                       22.041553  4.415240             7.112034
# 4                       21.319408  4.326240             6.462469
# ...                           ...       ...                  ...
# 2074                    24.996754  0.160042             0.908693
# 2075                    24.907140  0.175227             1.110894
# 2076                    25.685574  0.178591             0.058804
# 2077                    26.278778  0.122501             0.009576
# 2078                    25.562536  0.077976             0.789886
#
#       thermocline_nitrate_depthIntegral  QC_flag
# 0                              0.025728  include
# 1                              5.318187  include
# 2                              4.208444  include
# 3                              5.378340  include
# 4                              4.969550  include
# ...                                 ...      ...
# 2074                           0.170105  include
# 2075                           0.258762  include
# 2076                           0.105737  include
# 2077                           0.065285  include
# 2078                           0.110302  include
#
# [2079 rows x 18 columns]

# %%
pyg.walk(df)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00062c7926ee55e7O2QyWVEcXDK80TaN" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00062c7926ee55e7O2QyWVEcXDK80TaN") {
#             var iframe = document.getElementById("gwalker-00062c7926ee55e7O2QyWVEcXDK80TaN");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
